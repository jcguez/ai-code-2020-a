# %% [markdown]
# # Aceleradores descenso de gradiente

# %%
import numpy as np

# %%
def armijo_conditions(X,g,𝛼,f):
    
    c = 0.8

    if f(X-𝛼*g)<f(X)-c*𝛼*np.dot(g, g):
        return True
    return False

# %%
def backtracking(X,g,f):
    𝜌 = 0.9
    𝛼 = 100
    
    while True:
        if armijo_conditions(X,g,𝛼,f):
            return 𝛼
        𝛼 = 𝜌*𝛼

# %%
def gradientN(X,f,n):
    grad = np.zeros(n)
    h = 1e-12
    for i in range(0,n-1):
        e = np.zeros(n)
        e[i] = 1
        grad[i] = (f(X+e*h)-f(X))/h
    
    return grad

# %%
def rosenbrockN(X):
    sum = 0
    n = len(X)
    
    for i in range(0,n-2):
        sum = sum + (1-X[i])**2 + 100*(X[i+1]-X[i]**2)**2
    return sum

# %%
def nesterov(X,f):
    n = len(X)
    p = np.zeros(n)
    
    max_iter = 50000
    toler = 1e-5
    
    n1 = 0.9
    print("Empezando..")
    
    for i in range(0,max_iter):
        Xk = X - n1*p
        
        gk = gradientN(Xk,f,n)
        g = gradientN(X,f,n)
        α = backtracking(X,g,f) #* (-1)
        
        p = n1*p + (gk * α)
        
        if(np.linalg.norm(g)<toler):
            break
        print("Iteracion: "+str(i)+" \t||g||: "+str(np.linalg.norm(g)))
        #print("X: "+str(X))
        
        X = X - p
    print("Terminando..") 
    return X

# %% [markdown]
# ### Nesterov

# %% [markdown]
# $\hat{x}_k = x_k + \eta p_{k-1}$
#
# $g_k = -\alpha \nabla(f(\hat{x}))$
#
# $p_k =  g_k +   \eta p_{k-1}$
#
#
#
# $\eta \approx 0.9$

# %% [markdown]
# <img src = "nag.png" width = 300/>

# %%
n = 4
X = np.ones(n)
X[0] = 0

nesterov(X,rosenbrockN)
# Out:
# Empezando..
# Iteracion: 0 	||g||: 200.02781631237175
# Iteracion: 1 	||g||: 131.16317591599383
# Iteracion: 2 	||g||: 85.49828556054727
# Iteracion: 3 	||g||: 220.0013891455209
# Iteracion: 4 	||g||: 228.0781007888418
# Iteracion: 5 	||g||: 262.68038397692794
# Iteracion: 6 	||g||: 211.39724618921994
# Iteracion: 7 	||g||: 101.35660742069456
# Iteracion: 8 	||g||: 5.791556135817004
# Iteracion: 9 	||g||: 45.4130072942844
# Iteracion: 10 	||g||: 55.20470817755223
# Iteracion: 11 	||g||: 38.66877820868101
# Iteracion: 12 	||g||: 15.306547778023289
# Iteracion: 13 	||g||: 5.143371002707187
# Iteracion: 14 	||g||: 12.96234198572443
# Iteracion: 15 	||g||: 13.841492088272219
# Iteracion: 16 	||g||: 9.592315514419143
# Iteracion: 17 	||g||: 3.8552675794173092
# Iteracion: 18 	||g||: 2.1353574571331406
# Iteracion: 19 	||g||: 3.4960127370681433
# Iteracion: 20 	||g||: 3.7384669037801284
# Iteracion: 21 	||g||: 2.6350959472935895
# Iteracion: 22 	||g||: 1.6457226748100453
# Iteracion: 23 	||g||: 2.8467278259675872
# Iteracion: 24 	||g||: 2.7618167551420956
# Iteracion: 25 	||g||: 2.118988423365463
# Iteracion: 26 	||g||: 1.8259309461801523
# Iteracion: 27 	||g||: 1.392788259443318
# Iteracion: 28 	||g||: 1.0274258117885602
# Iteracion: 29 	||g||: 5.471730601612383
# Iteracion: 30 	||g||: 6.518837057963333
# Iteracion: 31 	||g||: 4.456208477816069
# Iteracion: 32 	||g||: 1.9528743184017117
# Iteracion: 33 	||g||: 1.627902392582183
# Iteracion: 34 	||g||: 1.122038296303761
# Iteracion: 35 	||g||: 0.7744245286316006
# Iteracion: 36 	||g||: 0.755415589462338
# Iteracion: 37 	||g||: 0.6277667498352595
# Iteracion: 38 	||g||: 2.478227844949062
# Iteracion: 39 	||g||: 2.917523984930178
# Iteracion: 40 	||g||: 2.067199770086551
# Iteracion: 41 	||g||: 1.0617191290750716
# Iteracion: 42 	||g||: 0.7624875904178958
# Iteracion: 43 	||g||: 0.5942607032672106
# Iteracion: 44 	||g||: 0.4551947058073188
# Iteracion: 45 	||g||: 3.5181751587924888
# Iteracion: 46 	||g||: 4.21383265600409
# Iteracion: 47 	||g||: 3.124185293130268
# Iteracion: 48 	||g||: 1.7154326253179133
# Iteracion: 49 	||g||: 1.0686608922508205
# Iteracion: 50 	||g||: 0.4884222824420091
# Iteracion: 51 	||g||: 0.47281901308625013
# Iteracion: 52 	||g||: 0.43340808378466933
# Iteracion: 53 	||g||: 0.3629706058951966
# Iteracion: 54 	||g||: 0.4573628375779218
# Iteracion: 55 	||g||: 0.3535813999563853
# Iteracion: 56 	||g||: 0.313324274017147
# Iteracion: 57 	||g||: 24.020157849457295
# Iteracion: 58 	||g||: 27.789360005436436
# Iteracion: 59 	||g||: 19.373249750885844
# Iteracion: 60 	||g||: 6.7528599230473
# Iteracion: 61 	||g||: 3.294627569584224
# Iteracion: 62 	||g||: 8.189236866042947
# Iteracion: 63 	||g||: 8.099234068268137
# Iteracion: 64 	||g||: 5.152982671820777
# Iteracion: 65 	||g||: 2.085698097162149
# Iteracion: 66 	||g||: 1.5212643598795317
# Iteracion: 67 	||g||: 1.1484244898822635
# Iteracion: 68 	||g||: 0.5137579243878877
# Iteracion: 69 	||g||: 0.171878221215533
# Iteracion: 70 	||g||: 0.32513112868734234
# Iteracion: 71 	||g||: 0.2746910687880805
# Iteracion: 72 	||g||: 0.13324031709570772
# Iteracion: 73 	||g||: 0.018435987331726526
# Iteracion: 74 	||g||: 0.1937952809743813
# Iteracion: 75 	||g||: 0.2349759587319496
# Iteracion: 76 	||g||: 0.1683282790190568
# Iteracion: 77 	||g||: 0.06900707221162615
# Iteracion: 78 	||g||: 0.04142986678683272
# Iteracion: 79 	||g||: 0.06345548271940223
# Iteracion: 80 	||g||: 0.061696353722551125
# Iteracion: 81 	||g||: 0.04480212964572896
# Iteracion: 82 	||g||: 0.07637263625256843
# Iteracion: 83 	||g||: 0.06943931098692736
# Iteracion: 84 	||g||: 0.051277291732018046
# Iteracion: 85 	||g||: 0.06437323945058558
# Iteracion: 86 	||g||: 0.05039183676940094
# Iteracion: 87 	||g||: 0.20405532645442004
# Iteracion: 88 	||g||: 0.2313735703830473
# Iteracion: 89 	||g||: 0.16228608928460847
# Iteracion: 90 	||g||: 0.07296922570401548
# Iteracion: 91 	||g||: 0.05309316607149415
# Iteracion: 92 	||g||: 0.879844005388178
# Iteracion: 93 	||g||: 1.0265571748842237
# Iteracion: 94 	||g||: 0.7098494026620475
# Iteracion: 95 	||g||: 0.26360775145075355
# Iteracion: 96 	||g||: 0.10414382628634698
# Iteracion: 97 	||g||: 0.19548993802238596
# Iteracion: 98 	||g||: 0.1661133594052387
# Iteracion: 99 	||g||: 0.09095499663773131
# Iteracion: 100 	||g||: 0.053362587142702825
# Iteracion: 101 	||g||: 40.98526525809117
# Iteracion: 102 	||g||: 48.116010998334346
# Iteracion: 103 	||g||: 34.280431747878126
# Iteracion: 104 	||g||: 13.88721323051825
# Iteracion: 105 	||g||: 3.1049948140133674
# Iteracion: 106 	||g||: 10.458262890733488
# Iteracion: 107 	||g||: 10.879586322515147
# Iteracion: 108 	||g||: 7.149051869179834
# Iteracion: 109 	||g||: 2.4602132752808705
# Iteracion: 110 	||g||: 1.2146525771135483
# Iteracion: 111 	||g||: 2.6253002664668914
# Iteracion: 112 	||g||: 2.3754064929182284
# Iteracion: 113 	||g||: 1.3227318074905934
# Iteracion: 114 	||g||: 0.312089953425476
# Iteracion: 115 	||g||: 0.32240073287874826
# Iteracion: 116 	||g||: 0.4608767263349467
# Iteracion: 117 	||g||: 0.384624684704247
# Iteracion: 118 	||g||: 0.2429010004073566
# Iteracion: 119 	||g||: 0.16597019400000365
# Iteracion: 120 	||g||: 0.10129211253011007
# Iteracion: 121 	||g||: 0.044206570582507966
# Iteracion: 122 	||g||: 0.11439035802714048
# Iteracion: 123 	||g||: 0.11791984374329718
# Iteracion: 124 	||g||: 0.08840527045720975
# Iteracion: 125 	||g||: 0.05230383007371549
# Iteracion: 126 	||g||: 0.05187456693700298
# Iteracion: 127 	||g||: 0.058807783053550236
# Iteracion: 128 	||g||: 0.047097938121771224
# Iteracion: 129 	||g||: 1.4614718916805292
# Iteracion: 130 	||g||: 1.7111661267625335
# Iteracion: 131 	||g||: 1.208409977285696
# Iteracion: 132 	||g||: 0.5235572055916284
# Iteracion: 133 	||g||: 0.2632760131256815
# Iteracion: 134 	||g||: 0.24211948552633691
# Iteracion: 135 	||g||: 0.16912558094934144
# Iteracion: 136 	||g||: 0.11562785148927945
# Iteracion: 137 	||g||: 0.11680246317947157
# Iteracion: 138 	||g||: 0.08882078375407039
# Iteracion: 139 	||g||: 0.049484999627626966
# Iteracion: 140 	||g||: 0.04709213614930967
# Iteracion: 141 	||g||: 0.06973763420862301
# Iteracion: 142 	||g||: 0.06457238964905591
# Iteracion: 143 	||g||: 0.05170908112752738
# Iteracion: 144 	||g||: 0.062210524799159846
# Iteracion: 145 	||g||: 0.052399945847234446
# Iteracion: 146 	||g||: 0.04379150467461084
# Iteracion: 147 	||g||: 0.18678143577279652
# Iteracion: 148 	||g||: 0.2177014391452929
# Iteracion: 149 	||g||: 0.15687350319627694
# Iteracion: 150 	||g||: 0.07672644605138772
# Iteracion: 151 	||g||: 0.05058791307520024
# Iteracion: 152 	||g||: 0.0801634209700777
# Iteracion: 153 	||g||: 0.0851867131075565
# Iteracion: 154 	||g||: 0.06279328381989105
# Iteracion: 155 	||g||: 0.04642021850392926
# Iteracion: 156 	||g||: 0.0728977553809849
# Iteracion: 157 	||g||: 0.07042993854474125
# Iteracion: 158 	||g||: 0.05317308696357287
# Iteracion: 159 	||g||: 0.041365704362694315
# Iteracion: 160 	||g||: 0.04732647020890697
# Iteracion: 161 	||g||: 0.03853111302871558
# Iteracion: 162 	||g||: 0.40734261571474845
# Iteracion: 163 	||g||: 0.48298593764551473
# Iteracion: 164 	||g||: 0.35798106392745327
# Iteracion: 165 	||g||: 0.18933944880914896
# Iteracion: 166 	||g||: 0.11017983300907298
# Iteracion: 167 	||g||: 0.048334002268758294
# Iteracion: 168 	||g||: 0.03664625523144172
# Iteracion: 169 	||g||: 0.16671175564546425
# Iteracion: 170 	||g||: 0.1994829950295932
# Iteracion: 171 	||g||: 0.1488040557069306
# Iteracion: 172 	||g||: 0.07064191579455192
# Iteracion: 173 	||g||: 0.033920146930077326
# Iteracion: 174 	||g||: 0.6382605842990106
# Iteracion: 175 	||g||: 0.7825865672567721
# Iteracion: 176 	||g||: 0.5603432199952644
# Iteracion: 177 	||g||: 0.22115259997813885
# Iteracion: 178 	||g||: 0.0619785071506841
# Iteracion: 179 	||g||: 0.15764226512014012
# Iteracion: 180 	||g||: 0.1523829361054083
# Iteracion: 181 	||g||: 0.09287243096500497
# Iteracion: 182 	||g||: 0.03482509732189967
# Iteracion: 183 	||g||: 0.03388700002034803
# Iteracion: 184 	||g||: 0.03019880252280906
# Iteracion: 185 	||g||: 0.11307336540420272
# Iteracion: 186 	||g||: 0.13406714178071505
# Iteracion: 187 	||g||: 0.09558129098667817
# Iteracion: 188 	||g||: 0.04177010442592348
# Iteracion: 189 	||g||: 0.028240560231878355
# Iteracion: 190 	||g||: 0.1927481121706265
# Iteracion: 191 	||g||: 0.2256904370172173
# Iteracion: 192 	||g||: 0.15624380630377482
# Iteracion: 193 	||g||: 0.060886308990276784
# Iteracion: 194 	||g||: 0.03088013922823603
# Iteracion: 195 	||g||: 0.03290394452075751
# Iteracion: 196 	||g||: 0.025384861721093766
# Iteracion: 197 	||g||: 0.09704881551372938
# Iteracion: 198 	||g||: 0.1082345001089927
# Iteracion: 199 	||g||: 0.07411922462726125
# Iteracion: 200 	||g||: 0.031771089700133336
# Iteracion: 201 	||g||: 0.02325793945478107
# Iteracion: 202 	||g||: 0.3163576403222761
# Iteracion: 203 	||g||: 0.3651279408525777
# Iteracion: 204 	||g||: 0.2476582224884548
# Iteracion: 205 	||g||: 0.08755617783395647
# Iteracion: 206 	||g||: 0.04195781383359217
# Iteracion: 207 	||g||: 0.07724947335580058
# Iteracion: 208 	||g||: 0.06857382534326437
# Iteracion: 209 	||g||: 0.03986680804354496
# Iteracion: 210 	||g||: 0.019640953230180395
# Iteracion: 211 	||g||: 0.261143079100913
# Iteracion: 212 	||g||: 0.29721871334972866
# Iteracion: 213 	||g||: 0.19929713626897808
# Iteracion: 214 	||g||: 0.06860820655268468
# Iteracion: 215 	||g||: 0.036349720016181
# Iteracion: 216 	||g||: 0.06357205742533169
# Iteracion: 217 	||g||: 0.05541531630851552
# Iteracion: 218 	||g||: 0.031917415752725296
# Iteracion: 219 	||g||: 0.01658952946529771
# Iteracion: 220 	||g||: 0.5417724074109356
# Iteracion: 221 	||g||: 0.6176589183161507
# Iteracion: 222 	||g||: 0.412118893456019
# Iteracion: 223 	||g||: 0.13697463291969086
# Iteracion: 224 	||g||: 0.06864141844526074
# Iteracion: 225 	||g||: 0.15093585532839976
# Iteracion: 226 	||g||: 0.13587396166333604
# Iteracion: 227 	||g||: 0.07415399539716754
# Iteracion: 228 	||g||: 0.01639156475935763
# Iteracion: 229 	||g||: 0.01272150653395549
# Iteracion: 230 	||g||: 0.14699818904767417
# Iteracion: 231 	||g||: 0.16648167313146667
# Iteracion: 232 	||g||: 0.1106934261747657
# Iteracion: 233 	||g||: 0.037384345798185864
# Iteracion: 234 	||g||: 0.021575304155855575
# Iteracion: 235 	||g||: 0.035798678386992744
# Iteracion: 236 	||g||: 0.030608796097866153
# Iteracion: 237 	||g||: 0.016583147446972736
# Iteracion: 238 	||g||: 0.009618113420934974
# Iteracion: 239 	||g||: 3.1064225191220647
# Iteracion: 240 	||g||: 3.7515036352807543
# Iteracion: 241 	||g||: 2.739961607220382
# Iteracion: 242 	||g||: 1.1597688034555638
# Iteracion: 243 	||g||: 0.1646010210544108
# Iteracion: 244 	||g||: 0.8609629952618073
# Iteracion: 245 	||g||: 0.9450642066770727
# Iteracion: 246 	||g||: 0.647394783191421
# Iteracion: 247 	||g||: 0.23953736335325088
# Iteracion: 248 	||g||: 0.08177009734522027
# Iteracion: 249 	||g||: 0.23505035163382937
# Iteracion: 250 	||g||: 0.23598191783772726
# Iteracion: 251 	||g||: 0.14976348834128814
# Iteracion: 252 	||g||: 0.04593312004716191
# Iteracion: 253 	||g||: 0.0311659610619407
# Iteracion: 254 	||g||: 0.058716555626513754
# Iteracion: 255 	||g||: 0.053097292164697274
# Iteracion: 256 	||g||: 0.030889065014510785
# Iteracion: 257 	||g||: 0.009837221587097433
# Iteracion: 258 	||g||: 0.008872748913494006
# Iteracion: 259 	||g||: 0.008703996716141589
# Iteracion: 260 	||g||: 0.054441825093895314
# Iteracion: 261 	||g||: 0.06529909773620549
# Iteracion: 262 	||g||: 0.05168998369467284
# Iteracion: 263 	||g||: 0.028127335366586827
# Iteracion: 264 	||g||: 0.009485460894666672
# Iteracion: 265 	||g||: 0.06064239879990044
# Iteracion: 266 	||g||: 0.06970534773504326
# Iteracion: 267 	||g||: 0.05007890010197718
# Iteracion: 268 	||g||: 0.020646204932968263
# Iteracion: 269 	||g||: 0.010436758162079686
# Iteracion: 270 	||g||: 0.018526926001828876
# Iteracion: 271 	||g||: 0.019560321828844436
# Iteracion: 272 	||g||: 0.012870617320274726
# Iteracion: 273 	||g||: 0.009160146873750262
# Iteracion: 274 	||g||: 0.7322078994700094
# Iteracion: 275 	||g||: 0.8666221102337486
# Iteracion: 276 	||g||: 0.6287820106764405
# Iteracion: 277 	||g||: 0.26243175299249955
# Iteracion: 278 	||g||: 0.043179282094814385
# Iteracion: 279 	||g||: 0.2004019009076138
# Iteracion: 280 	||g||: 0.216178079622736
# Iteracion: 281 	||g||: 0.14565295172614512
# Iteracion: 282 	||g||: 0.05217130553150389
# Iteracion: 283 	||g||: 0.0208381985991974
# Iteracion: 284 	||g||: 0.050659873830226666
# Iteracion: 285 	||g||: 0.04923207313316916
# Iteracion: 286 	||g||: 0.030464787008210276
# Iteracion: 287 	||g||: 0.009137096679943625
# Iteracion: 288 	||g||: 0.007062549609231599
# Iteracion: 289 	||g||: 0.010115790482084577
# Iteracion: 290 	||g||: 0.008118438393767989
# Iteracion: 291 	||g||: 0.0043086717910923444
# Iteracion: 292 	||g||: 0.0029100632823249126
# Iteracion: 293 	||g||: 0.19879287402351206
# Iteracion: 294 	||g||: 0.23920578421936564
# Iteracion: 295 	||g||: 0.1744680688990349
# Iteracion: 296 	||g||: 0.07365119259207924
# Iteracion: 297 	||g||: 0.01095885086552603
# Iteracion: 298 	||g||: 0.05144518360037346
# Iteracion: 299 	||g||: 0.055761425564641205
# Iteracion: 300 	||g||: 0.03781633068966822
# Iteracion: 301 	||g||: 0.013775011999701157
# Iteracion: 302 	||g||: 0.005208928227455573
# Iteracion: 303 	||g||: 0.013062490148297518
# Iteracion: 304 	||g||: 0.01283529398889492
# Iteracion: 305 	||g||: 0.008047703904254992
# Iteracion: 306 	||g||: 0.0025133797174720154
# Iteracion: 307 	||g||: 0.001770530604138369
# Iteracion: 308 	||g||: 0.0026197195687624733
# Iteracion: 309 	||g||: 0.0021369746183766162
# Iteracion: 310 	||g||: 0.0011329058046511667
# Iteracion: 311 	||g||: 0.0007229100854015798
# Iteracion: 312 	||g||: 0.04401011382688886
# Iteracion: 313 	||g||: 0.05305236259192549
# Iteracion: 314 	||g||: 0.038806753456929924
# Iteracion: 315 	||g||: 0.016483547314423256
# Iteracion: 316 	||g||: 0.0023397133368901553
# Iteracion: 317 	||g||: 0.011396344958132685
# Iteracion: 318 	||g||: 0.012418937076804073
# Iteracion: 319 	||g||: 0.008464551799223702
# Iteracion: 320 	||g||: 0.003122780822204548
# Iteracion: 321 	||g||: 0.001124065104201601
# Iteracion: 322 	||g||: 0.0028946513607931443
# Iteracion: 323 	||g||: 0.00286495526054366
# Iteracion: 324 	||g||: 0.0018092684828622462
# Iteracion: 325 	||g||: 0.0005441996997944737
# Iteracion: 326 	||g||: 0.00041819347210350025
# Iteracion: 327 	||g||: 0.0006005121013123617
# Iteracion: 328 	||g||: 0.00048096430209346755
# Iteracion: 329 	||g||: 0.000247628209297022
# Iteracion: 330 	||g||: 0.00015495298391139708
# Iteracion: 331 	||g||: 0.006484264162452765
# Iteracion: 332 	||g||: 0.007823268453409384
# Iteracion: 333 	||g||: 0.005727788642385372
# Iteracion: 334 	||g||: 0.0024386118032150876
# Iteracion: 335 	||g||: 0.00034762943197050593
# Iteracion: 336 	||g||: 0.0016798745081812545
# Iteracion: 337 	||g||: 0.0018333282863012134
# Iteracion: 338 	||g||: 0.0012522650491203606
# Iteracion: 339 	||g||: 0.00046633945388825806
# Iteracion: 340 	||g||: 0.00016259665462146631
# Iteracion: 341 	||g||: 0.00038687070859117086
# Iteracion: 342 	||g||: 0.00035632855460759763
# Iteracion: 343 	||g||: 0.00020004638764988623
# Iteracion: 344 	||g||: 5.852222221994309e-05
# Iteracion: 345 	||g||: 6.998451650629276e-05
# Iteracion: 346 	||g||: 4.97248363291161e-05
# Iteracion: 347 	||g||: 4.1931451738212235e-05
# Iteracion: 348 	||g||: 0.0005175278958366783
# Iteracion: 349 	||g||: 0.000620848280290192
# Iteracion: 350 	||g||: 0.0004535158936547075
# Iteracion: 351 	||g||: 0.00019359377834709637
# Iteracion: 352 	||g||: 3.6916065745323116e-05
# Iteracion: 353 	||g||: 5.7450216688587016e-05
# Iteracion: 354 	||g||: 4.71039599314008e-05
# Iteracion: 355 	||g||: 2.5829951707820346e-05
# Iteracion: 356 	||g||: 1.8618961584305308e-05
# Iteracion: 357 	||g||: 0.004685093482080125
# Iteracion: 358 	||g||: 0.005645766242531334
# Iteracion: 359 	||g||: 0.004130964575162382
# Iteracion: 360 	||g||: 0.001755804573747494
# Iteracion: 361 	||g||: 0.0002422155933125974
# Iteracion: 362 	||g||: 0.0012944392813961654
# Iteracion: 363 	||g||: 0.0014220398174693424
# Iteracion: 364 	||g||: 0.0009750799840141272
# Iteracion: 365 	||g||: 0.0003636721087396937
# Iteracion: 366 	||g||: 0.00012016532648448266
# Iteracion: 367 	||g||: 0.0003287677962674382
# Iteracion: 368 	||g||: 0.00032848184000134804
# Iteracion: 369 	||g||: 0.00020903711317971256
# Iteracion: 370 	||g||: 6.802702267808138e-05
# Iteracion: 371 	||g||: 4.516306998233303e-05
# Iteracion: 372 	||g||: 6.241943102269101e-05
# Iteracion: 373 	||g||: 4.9373947071166035e-05
# Iteracion: 374 	||g||: 3.1598346767922805e-05
# Iteracion: 375 	||g||: 3.873697170018598e-05
# Iteracion: 376 	||g||: 3.083717109485857e-05
# Iteracion: 377 	||g||: 0.00126497366279662
# Iteracion: 378 	||g||: 0.0015223969601652944
# Iteracion: 379 	||g||: 0.0011135410037523955
# Iteracion: 380 	||g||: 0.00047351708440755756
# Iteracion: 381 	||g||: 7.064982683465247e-05
# Iteracion: 382 	||g||: 0.000303034296190667
# Iteracion: 383 	||g||: 0.0003273921978595895
# Iteracion: 384 	||g||: 0.00022238589824408083
# Iteracion: 385 	||g||: 8.343612650231525e-05
# Iteracion: 386 	||g||: 3.5940897698477306e-05
# Iteracion: 387 	||g||: 5.2550676045516446e-05
# Iteracion: 388 	||g||: 4.203078534075945e-05
# Iteracion: 389 	||g||: 2.4954795319088983e-05
# Iteracion: 390 	||g||: 2.1453068314605826e-05
# Iteracion: 391 	||g||: 5.8135872685458116e-05
# Iteracion: 392 	||g||: 5.844132234409118e-05
# Iteracion: 393 	||g||: 3.6153662660484534e-05
# Iteracion: 394 	||g||: 1.9543813506463137e-05
# Iteracion: 395 	||g||: 0.00019715420745763376
# Iteracion: 396 	||g||: 0.0002351736977886192
# Iteracion: 397 	||g||: 0.00017148625355320227
# Iteracion: 398 	||g||: 7.378356041243003e-05
# Iteracion: 399 	||g||: 1.978569552549218e-05
# Iteracion: 400 	||g||: 4.037279648131404e-05
# Iteracion: 401 	||g||: 4.6371590639967694e-05
# Iteracion: 402 	||g||: 3.144515564938327e-05
# Iteracion: 403 	||g||: 1.68562002506159e-05
# Iteracion: 404 	||g||: 2.6510047780806135e-05
# Iteracion: 405 	||g||: 2.180603338047803e-05
# Iteracion: 406 	||g||: 1.5104257381597565e-05
# Iteracion: 407 	||g||: 0.00011665672341662634
# Iteracion: 408 	||g||: 0.0001379841154667242
# Iteracion: 409 	||g||: 0.00010069626086509487
# Iteracion: 410 	||g||: 4.148881232788694e-05
# Iteracion: 411 	||g||: 1.614508843934739e-05
# Iteracion: 412 	||g||: 1.571792856472845e-05
# Iteracion: 413 	||g||: 1.486575201760436e-05
# Iteracion: 414 	||g||: 1.7775212039474813e-05
# Iteracion: 415 	||g||: 1.7667613421842597e-05
# Iteracion: 416 	||g||: 1.5177617101048064e-05
# Iteracion: 417 	||g||: 1.3156434627730266e-05
# Iteracion: 418 	||g||: 2.6836544860703937e-05
# Iteracion: 419 	||g||: 2.9960684906547233e-05
# Iteracion: 420 	||g||: 2.0472576153587686e-05
# Iteracion: 421 	||g||: 1.199291284715465e-05
# Iteracion: 422 	||g||: 3.927870915022686e-05
# Iteracion: 423 	||g||: 4.2310611947025645e-05
# Iteracion: 424 	||g||: 2.8378030994389335e-05
# Iteracion: 425 	||g||: 1.3607074604400801e-05
# Iteracion: 426 	||g||: 1.1479244712611741e-05
# Iteracion: 427 	||g||: 1.0824846437255481e-05
# Iteracion: 428 	||g||: 0.00014408840437337775
# Iteracion: 429 	||g||: 0.00016489039267138174
# Iteracion: 430 	||g||: 0.00011490683943354615
# Iteracion: 431 	||g||: 5.538278173614869e-05
# Iteracion: 432 	||g||: 3.2720887125216553e-05
# Iteracion: 433 	||g||: 1.8006935621225003e-05
# Iteracion: 434 	||g||: 1.1022287416304214e-05
# Iteracion: 435 	||g||: 1.1097924676861997e-05
# Terminando..
# Iteracion: 436 	||g||: 8.571269405231806e-06
# array([0.99999624, 0.99999247, 0.9999849 , 1.        ])
